# %%
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
X=np.array([1,2,3,4,5])
Y=X**2

# %%
plt.plot(X,Y)

# %%
x = np.arange(1,16)
y = x**2
z = (y/2)+40

# %%
fig = plt.figure()

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="g",label='line1' )

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="g",label='line1' )
ax.plot(x,z,color="r",label='line2')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')
ax.set_title('Title of the Plot',fontsize=15)    
ax.set_xlabel('Label for X axis',fontsize=15)    
ax.set_ylabel('Label for Y axis',fontsize=15)
# Out:
# Text(0, 0.5, 'Label for Y axis')

# %%
fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
ax.plot(x,y,color="g", label='line1' )
ax.plot(x,z,color="r", label='line2')
ax.set_title('Title of the Plot',fontsize=15)    
ax.set_xlabel('Label for X axis',fontsize=15)    
ax.set_ylabel('Label for Y axis',fontsize=15)   
ax.legend()

# %%
x = np.arange(1,16)   
y = x**2    
z = (y/2)+40   
fig = plt.figure(figsize=(8,5))
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.10,0.42,0.45,0.45])
ax1.plot(x,y,color="g", label='line1')
ax1.set_title('Title for Plot 1',fontsize=15)    
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)  
ax1.legend()    
ax2.legend()

# %%
x = np.arange(1,16)   
y = x**2    
z = (y/2)+40   
fig = plt.figure(figsize=(8,8))

ax1 = fig.add_axes([0,0,0.5,0.5])
ax2 = fig.add_axes([0.6,0,0.5,0.5])
ax3 = fig.add_axes([0,0.6,0.5,0.5])
ax4 = fig.add_axes([0.6,0.6,0.5,0.5])

ax1.plot(x,y,color="g", label='line1')
ax1.set_title('Title for Plot 1',fontsize=15)    
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    

ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)  

ax3.plot(x,y,color="b", label='line1')
ax3.set_title('Title for Plot 1',fontsize=15)    
ax3.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax3.set_ylabel('Plot 1 - Y axis',fontsize=15)

ax4.plot(x,y,color="y", label='line1')
ax4.set_title('Title for Plot 1',fontsize=15)    
ax4.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax4.set_ylabel('Plot 1 - Y axis',fontsize=15)

ax1.legend()    
ax2.legend()

# %%
x = np.arange(1,16)   
y = x**2    
z = (y/2)+40   
fig, (ax1, ax2) = plt.subplots(1, 2)    
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)   
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)  
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)
# Out:
# Text(0, 0.5, 'Plot 2 - Y axis')

# %%
x = np.arange(1,16)    
y = x**2    
z = (y/2)+40   
fig, (ax1, ax2) = plt.subplots(1, 2)    
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)   
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)   
ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)   
fig.tight_layout()

# %%
#creating sample data for plotting
x = np.arange(1,16)    #1 … 15
y = x**2    #square of x values
z = (y/2)+40    #arithmetic operation applied to y values
#creating an empty canvas/figure
fig = plt.figure(figsize=(8,8))
#setting axes as [left, bottom, width, height]
ax1 = fig.add_axes([0,0,0.5,0.5])
ax2 = fig.add_axes([0.6,0,0.5,0.5])
ax3 = fig.add_axes([0,0.6,0.5,0.5])
ax4 = fig.add_axes([0.6,0.6,0.5,0.5])
#plotting the lines
ax1.plot(x,y,color="g", label='line1' )
ax1.set_title('Title for Plot 1',fontsize=15)    #setting title
ax1.set_xlabel('Plot 1 - X axis',fontsize=15)    # setting X label
ax1.set_ylabel('Plot 1 - Y axis',fontsize=15)    # setting Y _label
ax1.legend()

ax2.plot(x,z,color="r", label='line2')
ax2.set_title('Title for Plot 2',fontsize=15)    #setting title
ax2.set_xlabel('Plot 2 - X axis',fontsize=15)    # setting X label
ax2.set_ylabel('Plot 2 - Y axis',fontsize=15)    # setting Y _label
ax2.legend()

ax3.plot(x,y,color="b", label='line3' )
ax3.set_title('Title for Plot 3',fontsize=15)    #setting title
ax3.set_xlabel('Plot 3 - X axis',fontsize=15)    # setting X label
ax3.set_ylabel('Plot 3 - Y axis',fontsize=15)    # setting Y _label
ax3.legend()

ax4.plot(x,z,color="y", label='line4')
ax4.set_title('Title for Plot 4',fontsize=15)    #setting title
ax4.set_xlabel('Plot 4 - X axis',fontsize=15)    # setting X label
ax4.set_ylabel('Plot 4 - Y axis',fontsize=15)    # setting Y _label
ax4.legend()

# %%
import matplotlib.pyplot as plt
import numpy as np
x=[10,20,30,40,50,60]
y=[1,2,3,4,5,6]
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.bar(x,y)
# Out:
# <BarContainer object of 6 artists>

# %%
#importing the data
import pandas as pd
df = pd.read_csv('dataset/auto_mpg.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
#replacing the null values in 'horsepower' with its mean value
df['horsepower'].fillna(df['horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
import matplotlib.pyplot as plt
import numpy as np
x= df['horsepower']
y= df['mpg']
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.scatter(x,y)

# %%
df.groupby('model_year').count()['name']
# Out:
# model_year
# 70    29
# 71    28
# 72    28
# 73    40
# 74    27
# 75    30
# 76    34
# 77    28
# 78    36
# 79    29
# 80    29
# 81    29
# 82    31
# Name: name, dtype: int64

# %%
import matplotlib.pyplot as plt
import numpy as np
df_new = df.groupby('model_year').count()[['name']]
df_new.reset_index(inplace = True)
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.bar(df_new['model_year'],df_new['name'])
# Out:
# <BarContainer object of 13 artists>

# %%
import matplotlib.pyplot as plt
import numpy as np

#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.hist(df['horsepower'], bins=20)
# Out:
# (array([13., 14., 55., 40., 67., 53., 40., 10.,  8., 11., 18., 29.,  7.,
#          6., 10.,  4.,  3.,  2.,  4.,  4.]),
#  array([ 46. ,  55.2,  64.4,  73.6,  82.8,  92. , 101.2, 110.4, 119.6,
#         128.8, 138. , 147.2, 156.4, 165.6, 174.8, 184. , 193.2, 202.4,
#         211.6, 220.8, 230. ]),
#  <BarContainer object of 20 artists>)

# %%
new_df = df.groupby('origin').count()[['name']]
new_df.reset_index(inplace=True)

# %%
import matplotlib.pyplot as plt
import numpy as np
new_df = df.groupby('origin').count()[['name']]
new_df.reset_index(inplace=True)
colors = ['red', 'green', 'blue' ]
explode = [0.05, 0, 0]
#creating an empty canvas/figure
fig = plt.figure()
#setting axes
ax = fig.add_axes([0,0,1,1])
#plotting the lines
ax.pie(new_df['name'], labels=new_df['origin'], colors = colors, explode = explode, autopct='%0.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x202b63bb110>,
#   <matplotlib.patches.Wedge at 0x202b5253a10>,
#   <matplotlib.patches.Wedge at 0x202b52650d0>],
#  [Text(0.9788723988472815, 0.6035800085945263, 'europe'),
#   Text(-0.1729355121735563, 1.0863209970488787, 'japan'),
#   Text(-0.4229564276124259, -1.0154348134377384, 'usa')],
#  [Text(0.5532757036962895, 0.34115391790125404, '17.6%'),
#   Text(-0.09432846118557615, 0.5925387256630247, '19.8%'),
#   Text(-0.2307035059704141, -0.5538735346024027, '62.6%')])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

sns.scatterplot(x='horsepower', y='mpg', hue='origin', style='cylinders',data=df)
# Out:
# <Axes: xlabel='horsepower', ylabel='mpg'>

# %%
import pandas as pd
df = pd.read_csv('dataset/auto_mpg.csv')
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    392 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
# dtypes: float64(4), int64(3), object(2)
# memory usage: 28.1+ KB

# %%
df['horsepower'].fillna(df['horsepower'].mean(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   mpg           398 non-null    float64
#  1   cylinders     398 non-null    int64
#  2   displacement  398 non-null    float64
#  3   horsepower    398 non-null    float64
#  4   weight        398 non-null    int64
#  5   acceleration  398 non-null    float64
#  6   model_year    398 non-null    int64
#  7   origin        398 non-null    object
#  8   name          398 non-null    object
#  9   city_mileage  398 non-null    float64
# dtypes: float64(5), int64(3), object(2)
# memory usage: 31.2+ KB

# %%
df['mpg'].unique()
# Out:
# array([18. , 15. , 16. , 17. , 14. , 24. , 22. , 21. , 27. , 26. , 25. ,
#        10. , 11. ,  9. , 28. , 19. , 12. , 13. , 23. , 30. , 31. , 35. ,
#        20. , 29. , 32. , 33. , 17.5, 15.5, 14.5, 22.5, 24.5, 18.5, 29.5,
#        26.5, 16.5, 31.5, 36. , 25.5, 33.5, 20.5, 30.5, 21.5, 43.1, 36.1,
#        32.8, 39.4, 19.9, 19.4, 20.2, 19.2, 25.1, 20.6, 20.8, 18.6, 18.1,
#        17.7, 27.5, 27.2, 30.9, 21.1, 23.2, 23.8, 23.9, 20.3, 21.6, 16.2,
#        19.8, 22.3, 17.6, 18.2, 16.9, 31.9, 34.1, 35.7, 27.4, 25.4, 34.2,
#        34.5, 31.8, 37.3, 28.4, 28.8, 26.8, 41.5, 38.1, 32.1, 37.2, 26.4,
#        24.3, 19.1, 34.3, 29.8, 31.3, 37. , 32.2, 46.6, 27.9, 40.8, 44.3,
#        43.4, 36.4, 44.6, 40.9, 33.8, 32.7, 23.7, 23.6, 32.4, 26.6, 25.8,
#        23.5, 39.1, 39. , 35.1, 32.3, 37.7, 34.7, 34.4, 29.9, 33.7, 32.9,
#        31.6, 28.1, 30.7, 24.2, 22.4, 34. , 38. , 44. ])

# %%
df['mpg'].describe()
# Out:
# count    398.000000
# mean      23.514573
# std        7.815984
# min        9.000000
# 25%       17.500000
# 50%       23.000000
# 75%       29.000000
# max       46.600000
# Name: mpg, dtype: float64

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[6,6])
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of mileage')
ax.boxplot(df['mpg'])
fig.show()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\3994527226.py:6: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
df[df['mpg'] == 9]
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 28  9.0          8         304.0       193.0    4732          18.5
#
#     model_year origin      name  city_mileage
# 28          70    usa  hi 1200d          6.75

# %%
df['city_mileage']=df['mpg']*0.75
df.head()
# Out:
#     mpg  cylinders  displacement  horsepower  weight  acceleration  \
# 0  18.0          8         307.0       130.0    3504          12.0
# 1  15.0          8         350.0       165.0    3693          11.5
# 2  18.0          8         318.0       150.0    3436          11.0
# 3  16.0          8         304.0       150.0    3433          12.0
# 4  17.0          8         302.0       140.0    3449          10.5
#
#    model_year origin                       name  city_mileage
# 0          70    usa  chevrolet chevelle malibu         13.50
# 1          70    usa          buick skylark 320         11.25
# 2          70    usa         plymouth satellite         13.50
# 3          70    usa              amc rebel sst         12.00
# 4          70    usa                ford torino         12.75

# %%
mpg_list = [df['mpg'],df['city_mileage']]
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[6,5])
ax = fig.add_axes([0, 0, 1, 1])
ax.set_title('Distribution of Average MPG vs City MPG')
ax.set_ylabel('Mileage per gallon')
ax.boxplot(mpg_list,widths = 0.5)
fig.show()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\472275219.py:8: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
line_df=df.groupby(by=['model_year'])
line_df = line_df.mean()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\1786535244.py:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   line_df = line_df.mean()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[8,4])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df['mpg']/10,label='Mileage /10')
ax.plot(line_df['weight']/1000,label='Weight /1000')
ax.plot(line_df['horsepower']/100,label='Horsepower /100')
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\1014653196.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[8,4])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df['mpg']/10,label='Mileage', linestyle='-',linewidth=2)
ax.plot(line_df['weight']/1000,label='Weight',linestyle=':',linewidth=3)
ax.plot(line_df['horsepower']/100,label='Horsepower',linestyle='--',linewidth=3)
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\2742977144.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[10,5])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df['mpg']/10,label='Mileage')
ax.plot(line_df['weight']/1000,label='Weight')
ax.plot(line_df['horsepower']/100,label='Horsepower')
plt.text(75.5, 1.14, 'Horsepower',
             va = 'center', #va -> vertical alignment
             rotation = 4, #angle
             bbox = dict( 
                     boxstyle = 'round',
                     facecolor = 'wheat',
                     alpha = 0.3)) #background style
plt.text(75.5, 2.25, 'Mileage',va = 'center',rotation = 17,bbox = dict(boxstyle = 'round',facecolor = 'wheat',alpha = 0.3))
plt.text(76, 3.15, 'Weight',va = 'center',rotation = -13,bbox = dict(boxstyle = 'round',facecolor = 'wheat',alpha = 0.3))
plt.annotate('Highest Mileage', xy=(80.1, 3.39), xytext=(80.5, 3.38), arrowprops=dict(facecolor='wheat', shrink=.01))
plt.annotate('Lowest Mileage', xy=(73.05, 1.70), xytext=(73.5, 1.69), arrowprops=dict(facecolor='wheat', shrink=.01))
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
fig.show()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\1000747784.py:21: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
import matplotlib.pyplot as plt
fig = plt.figure(figsize=[8,4])
ax = fig.add_axes([0, 0, 1, 1])
ax.plot(line_df['mpg']/10,label='Mileage', color="g", marker='+', markersize = 7)
ax.plot(line_df['weight']/1000,label='Weight', color="b", marker='o', markersize = 7)
ax.plot(line_df['horsepower']/100,label='Horsepower', color="r", marker='s', markersize = 7)
ax.set_title('Mileage vs Weight vs Horsepower',fontsize = 17)
ax.set_ylabel('Value',fontsize=12)
ax.set_xlabel('Model year',fontsize=12)
ax.legend()
fig.show()
# Out:
# C:\Users\bldea6\AppData\Local\Temp\ipykernel_8532\3880827300.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
